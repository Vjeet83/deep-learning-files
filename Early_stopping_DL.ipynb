# %%
pip install mlxtend
# Out:
# ...
#
#   Obtaining dependency information for mlxtend from https://files.pythonhosted.org/packages/73/da/d5d77a9a7a135c948dbf8d3b873655b105a152d69e590150c83d23c3d070/mlxtend-0.23.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB 7.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.4 MB 7.9 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 7.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.4 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 5.8 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
x,y = make_circles(n_samples=100,noise =0.1,random_state=1)

# %%
sns.scatterplot(x=x[:,0],y=x[:,1],hue=y)
# Out:
# <Axes: >

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=444)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss = 'binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=3500, verbose=0)

# %%
plt.plot(history.history['loss'],label='train')
plt.plot(history.history['val_loss'],label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(x_test,y_test.ravel(),clf=model,legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 14s 1ms/step

# %% [markdown]
# #  Early stopping

# %%
model= Sequential()

model.add(Dense(256,input_dim=2,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
callback=EarlyStopping(
    monitor = 'val_loss',
    min_delta=0.00001,
    patience= 40,
    verbose=1,
    mode='auto',
    baseline=None,
    restore_best_weights=False
)

# %%
''' 
yaha 
monitor = kis base pr mazor krna h loss ya accuracy 
min_delta = 
patient = kitni bar same loss\accuracy  same repeate hone tak rukna h
veerbose = 0 or 1 , matlab last me early_stopping likha hua chahie ya nahi
mode = ye monitor pr depende karta h islia auto hi rahne do 
base line = 
restore_best_weight = true\false ,weights vo lene h kya jis pr 
                       accuracy max aa rahi thi  

'''
# Out:
# ' \nyaha \nmonitor = kis base pr mazor krna h loss ya accuracy \nmin_delta = \npatient = kitni bar same loss\x07ccuracy  same repeate hone tak rukna h\nveerbose = 0 or 1 , matlab last me early_stopping likha hua chahie ya nahi\nmode = ye monitor pr depende karta h islia auto hi rahne do \nbase line = \nrestore_best_weight = true\x0calse ,weights vo lene h kya jis pr \n                       accuracy max aa rahi thi  \n\n'

# %%
history=model.fit(x_train,y_train,validation_data=(x_test,y_test,),epochs=3500,callbacks=callback)
# Out:
# Epoch 1/3500
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3448 - accuracy: 0.8750 - val_loss: 0.5404 - val_accuracy: 0.7500
# Epoch 2/3500
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3439 - accuracy: 0.8750 - val_loss: 0.5378 - val_accuracy: 0.7500
# Epoch 3/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3433 - accuracy: 0.8750 - val_loss: 0.5304 - val_accuracy: 0.7000
# Epoch 4/3500
# 3/3 [==============================] - 0s 21ms/step - loss: 0.3428 - accuracy: 0.8750 - val_loss: 0.5291 - val_accuracy: 0.7000
# Epoch 5/3500
# 3/3 [==============================] - 0s 29ms/step - loss: 0.3429 - accuracy: 0.8750 - val_loss: 0.5260 - val_accuracy: 0.7000
# Epoch 6/3500
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3414 - accuracy: 0.8750 - val_loss: 0.5305 - val_accuracy: 0.7000
# Epoch 7/3500
# ...

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(x_test,y_test.ravel(),clf=model,legend=2)
plt.show()
# Out:
# 9600/9600 [==============================] - 16s 2ms/step
